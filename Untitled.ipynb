# %%
import pandas as pd

filename = 'data/covidtesting.csv'
df = pd.read_csv(filename)
df.tail()
# Out:
#     Reported Date  Confirmed Negative  Presumptive Negative  \
# 328    2020-12-30                 NaN                   NaN
# 329    2020-12-31                 NaN                   NaN
# 330    2021-01-01                 NaN                   NaN
# 331    2021-01-02                 NaN                   NaN
# 332    2021-01-03                 NaN                   NaN
#
#      Presumptive Positive  Confirmed Positive  Resolved  Deaths  Total Cases  \
# 328                   NaN             20558.0  153799.0  4474.0     178831.0
# 329                   NaN             21617.0  156012.0  4530.0     182159.0
# 330                   NaN             21582.0  158472.0  4581.0     184635.0
# 331                   NaN             22847.0  160526.0  4625.0     187998.0
# 332                   NaN             23611.0  162701.0  4650.0     190962.0
#
#      Total patients approved for testing as of Reporting Date  \
# 328                                          7858200.0
# ...

# %%
df.plot(x="Reported Date", y="Confirmed Positive")

# %%
df["date"] = pd.to_datetime(df["Reported Date"])
df.dtypes
# Out:
# Reported Date                                                       object
# Confirmed Negative                                                 float64
# Presumptive Negative                                               float64
# Presumptive Positive                                               float64
# Confirmed Positive                                                 float64
# Resolved                                                           float64
# Deaths                                                             float64
# Total Cases                                                        float64
# Total patients approved for testing as of Reporting Date           float64
# Total tests completed in the last day                              float64
# Percent positive tests in last day                                 float64
# Under Investigation                                                  int64
# ...
